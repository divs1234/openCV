# %%
import numpy as np
import cv2

face_cascade = cv2.CascadeClassifier('C:\\Users\\divya\\Anaconda3\\Library\\etc\\haarcascades\\haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('C:\\Users\\divya\\Anaconda3\\Library\\etc\\haarcascades\\haarcascade_eye.xml')

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
face_name = input('\nenter user name end press enter\n')

count = 0

while 1:
    ret, img = cap.read()
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(img, 1.3, 5)

    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),1)
        roi_gray = gray[y:import numpy as np
import cv2

face_cascade = cv2.CascadeClassifier('C:\\Users\\divya\\Anaconda3\\Library\\etc\\haarcascades\\haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('C:\\Users\\divya\\Anaconda3\\Library\\etc\\haarcascades\\haarcascade_eye.xml')

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
face_name = input('\nenter user name end press enter\n')

count = 0

while 1:
    ret, img = cap.read()
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(img, 1.3, 5)

    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),1)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        
        count += 1
        cv2.imwrite("dataset/User." + str(face_name) + '.' + str(count) + ".jpg", gray[y:y+h,x:x+w])
        cv2.imshow('image', img)

    cv2.imshow('img',img)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
    elif count >= 30:
         break

cap.release()
cv2.destroyAllWindows()
y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        
        count += 1
        cv2.imwrite("dataset/User." + str(face_name) + '.' + str(count) + ".jpg", gray[y:y+h,x:x+w])
        cv2.imshow('image', img)

    cv2.imshow('img',img)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
    elif count >= 30:
         break

cap.release()
cv2.destroyAllWindows()
